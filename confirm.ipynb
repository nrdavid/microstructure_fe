# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler,StandardScaler

df = pd.read_csv("data/morphological_data.csv")
print(np.sum(df[df["picture"] == "micrograph3"]["area"])*(0.0606060606**2))
#df[df["picture"] == "micrograph3"]
# labels = df["phase_number"]
# label_names = df["phase"]
# drop_cols = ["phase_number", "phase", "picture", "pic_height", "pic_width"]
# df_new = df.drop(columns=drop_cols)
# np_props = df_new.to_numpy()
# tsne = TSNE(n_components=2, verbose=1, init='random', perplexity=30)
# scaler = StandardScaler()
# scaled_dat = scaler.fit_transform(np_props)
# kmeans = KMeans(n_clusters=5)
# z = tsne.fit_transform(scaled_dat)
# df_plot = pd.DataFrame()
# df_plot["y"] = labels.to_numpy().astype(int)
# df_plot["comp-1"] = z[:,0]
# df_plot["comp-2"] = z[:,1]
# plt.clf()
# sns_plot = sns.scatterplot(x="comp-1", y="comp-2", hue=df_plot.y.tolist(),
#             palette=sns.color_palette("hls", max(df_plot.y.tolist())+1),
#             data=df_plot)
# sns_plot.set(title="Morphology Data Projection of Hand Labeled Micrographs")
# sns_plot.figure.savefig("confirmation_tsne_plot.png")
# Out:
# 153.52887157303212

# %%
df_test = pd.read_pickle("tom_final.pkl")
df_test.head()
# for x in df_test.columns:
#     print(x)
# Out:
#     area  area_bbox  area_filled  area_convex  axis_major_length  \
# 0    847       1260          847          997          60.541984
# 1    574       2739          574         1464          76.017038
# 2    732       1360          732          998          71.615031
# 3   5466       7620         5466         6392         124.008665
# 4  15577      46426        15577        28222         321.464488
#
#    axis_minor_length  eccentricity  equivalent_diameter_area  euler_number  \
# 0          18.812195      0.950498                 32.839517             1
# 1          24.623326      0.946085                 27.034043             1
# 2          17.035235      0.971296                 30.528861             1
# 3          60.712393      0.871957                 83.423782            -5
# 4         116.150500      0.932443                140.830580            -6
#
#      extent  feret_diameter_max  intensity_max  intensity_mean  intensity_min  \
# ...
